# %%
import pandas as pd

# %%
cdc_df = pd.read_csv('CDC-leading-causes-of-death-united-states-1980-2009.csv')
cdc_df.head()
# Out:
#     Rank order        Group  Year            Cause of death  Flag     Deaths
# 0          NaN  All persons  1980                All causes   NaN  1989841.0
# 1          1.0  All persons  1980         Diseases of heart   NaN   761085.0
# 2          2.0  All persons  1980       Malignant neoplasms   NaN   416509.0
# 3          3.0  All persons  1980  Cerebrovascular diseases   NaN   170225.0
# 4          4.0  All persons  1980    Unintentional injuries   NaN   105718.0

# %%
cdc_df.count()
# Out:
#  Rank order       360
# Group             396
# Year              396
# Cause of death    363
# Flag                1
# Deaths            363
# dtype: int64

# %%
cdc_df.drop(columns='Flag', inplace=True)

# %%
# cdc_df.count()

# %%
cdc_df.dropna(how='any', inplace = True)

# %%
# cdc_df.count()
# Out:
#  Rank order       330
# Group             330
# Year              330
# Cause of death    330
# Deaths            330
# dtype: int64

# %%
cdc_df.groupby(['Year', 'Group']).first()
# Out:
#                                                Rank order  \
# Year Group
# 1980 All persons                                      1.0
#      American Indian or Alaska Native                 1.0
#      American Indian or Alaska Native female          1.0
#      American Indian or Alaska Native male            1.0
#      Asian or Pacific Islander                        1.0
#      Asian or Pacific Islander female                 3.0
#      Asian or Pacific Islander male                   1.0
#      Black or African American                        1.0
#      Black or African American female                 1.0
#      Black or African American male                   1.0
#      Female                                           1.0
#      Male                                             1.0
#      White                                            1.0
#      White female                                     1.0
#      White male                                       1.0
# ...
